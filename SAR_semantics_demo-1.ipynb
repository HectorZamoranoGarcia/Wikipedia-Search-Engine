# %% [markdown]
# <h5></h5>
# <h1 style="display:block; margin-top:5px;" align="center">Búsqueda semántica</h1>
# <h3 style="display:block; margin-top:5px;" align="center">SAR: Sistemas de Almacenamiento y Recuperación de Información</h3>
# <h3 style="display:block; margin-top:5px;" align="center">GII</h3>
# <h3 style="display:block; margin-top:5px;" align="center">ETSInf. Universitat Politècnica de València</h3>
# <h3 style="display:block; margin-top:5px;" align="center">2024-2025</h3>
# <br>

# %%
COLAB = False # IF YOU USE GOOGLE COLAB -> COLAB = True
PIP = False # IF YOU NEED INSTALL THE LIBRARIES -> PIP = True
DOWNLOAD = False # LOAD SPACY MODEL

# %%
if PIP:
    # !pip install numpy
    # !pip install torch
    # !pip install scikit-learn
    # !pip install sentence-transformers
    # !pip install tqdm
    # !python -m spacy download es_core_news_lg

# %%
if DOWNLOAD:
  # !python -m spacy download es_core_news_lg

# %%
if COLAB is True:
  import sys
  from google.colab import drive
  drive.mount('/content/drive')
  base_path = "/content/drive/MyDrive/docencia/SAR"
  library_path = base_path
  sys.path.append(library_path)
else:
  base_path = "."

# %%
from SAR_semantics import SpacyStaticModel, BetoEmbeddingModel, BetoEmbeddingCLSModel, SentenceBertEmbeddingModel
import time
import os

models = {
    "SpacyStatic_noSW_noAlpha": SpacyStaticModel(),
    "SpacyStatic2_noAlpha": SpacyStaticModel(remove_stopwords=False),
    "SpacyStatic3_noSW": SpacyStaticModel(remove_noalpha=False),
    "SpacyStatic4": SpacyStaticModel(remove_stopwords=False, remove_noalpha=False),
    "BETO": BetoEmbeddingModel(),
    "BETOCLS": BetoEmbeddingCLSModel(),
    "Sentence-BERT": SentenceBertEmbeddingModel()
}

with open(os.path.join(base_path, "frases.txt")) as fh:
    texts = fh.read().splitlines()

for name, model in models.items():
    t0 = time.time()
    print(f"Indexing text using {name} ...", end='')
    model.fit(texts)  # Generar embeddings y construir el KDTree
    t1 = time.time() - t0
    print(f"done in {t1:0.3} seconds\n")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/310 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/134 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: dccuchile/bert-base-spanish-wwm-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# pooler.dense.weight                        | MISSING    |
# pooler.dense.bias                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: dccuchile/bert-base-spanish-wwm-uncased
# Key                                        | Status     |
# -------------------------------------------+------------+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |
# cls.predictions.decoder.bias               | UNEXPECTED |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |
# cls.predictions.transform.dense.bias       | UNEXPECTED |
# cls.predictions.bias                       | UNEXPECTED |
# cls.predictions.decoder.weight             | UNEXPECTED |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |
# pooler.dense.weight                        | MISSING    |
# pooler.dense.bias                          | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/701 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Indexing text using SpacyStatic_noSW_noAlpha ...done in 2.22 seconds
#
# Indexing text using SpacyStatic2_noAlpha ...done in 2.26 seconds
#
# Indexing text using SpacyStatic3_noSW ...done in 2.13 seconds
#
# Indexing text using SpacyStatic4 ...done in 2.18 seconds
#
# Indexing text using BETO ...done in 23.6 seconds
#
# Indexing text using BETOCLS ...done in 25.5 seconds
#
# Indexing text using Sentence-BERT ...done in 19.2 seconds

# %%
query = input("Query:")
while len(query) > 0:
    # Consulta
    top_k = 3
    for model_name, model in models.items():
        print(f"\nResults with {model_name}:")
        results = model.query(query, top_k)
        for distance, indx in results:
            print(f"  Phrase: {texts[indx]} | Distance: {distance:.4f}")
    query = input("\n\nQuery:")
# Out:
# Query:la perro y el gato corren juntos
#
# Results with SpacyStatic_noSW_noAlpha:
#   Phrase: El perro de mi vecino ladra cada vez que alguien pasa por la calle, lo cual puede ser molesto. | Distance: 15.6846
#   Phrase: Mi prima adoptó un perro que fue rescatado de las calles, y ahora es parte de la familia. | Distance: 17.1582
#   Phrase: Mi gato se metió en la caja del paquete como si fuera su nuevo castillo personal. | Distance: 17.4108
#
# Results with SpacyStatic2_noAlpha:
#   Phrase: Vimos un ciervo cruzando el camino cuando íbamos de excursión por la montaña. | Distance: 13.5488
#   Phrase: Mientras caminábamos por el casco antiguo de la ciudad, descubrimos una librería escondida. | Distance: 14.2414
#   Phrase: La ética animal aboga por el trato justo y compasivo hacia todas las especies en nuestra interacción con ellas. | Distance: 14.4897
#
# Results with SpacyStatic3_noSW:
#   Phrase: El perro de mi vecino ladra cada vez que alguien pasa por la calle, lo cual puede ser molesto. | Distance: 16.2228
#   Phrase: Mi gato se metió en la caja del paquete como si fuera su nuevo castillo personal. | Distance: 17.8692
#   Phrase: El niño se emocionó tanto al ver los fuegos artificiales que no podía dejar de sonreír. | Distance: 18.5527
#
# Results with SpacyStatic4:
#   Phrase: Vimos un ciervo cruzando el camino cuando íbamos de excursión por la montaña. | Distance: 13.2875
#   Phrase: Mi gato se metió en la caja del paquete como si fuera su nuevo castillo personal. | Distance: 13.8050
#   Phrase: Estuvimos todo el día arreglando el jardín para que luzca bien en la primavera. | Distance: 14.0021
#
# Results with BETO:
#   Phrase: La plaza estaba llena de niños jugando, padres charlando y músicos callejeros. | Distance: 13.6748
#   Phrase: El profesor explicó el tema con tanta claridad que todos comprendimos a la primera. | Distance: 14.7967
#   Phrase: Desde la ventana del avión se podía ver cómo el sol se ocultaba detrás de las nubes. | Distance: 15.1147
#
# Results with BETOCLS:
#   Phrase: Cada vez que paso por esa calle, me acuerdo de mis paseos de infancia. | Distance: 20.8302
#   Phrase: La plaza estaba llena de niños jugando, padres charlando y músicos callejeros. | Distance: 20.8523
#   Phrase: Desde la ventana del avión se podía ver cómo el sol se ocultaba detrás de las nubes. | Distance: 21.0793
#
# Results with Sentence-BERT:
#   Phrase: Mi prima adoptó un perro que fue rescatado de las calles, y ahora es parte de la familia. | Distance: 20.1064
#   Phrase: Mi gato se metió en la caja del paquete como si fuera su nuevo castillo personal. | Distance: 21.5595
#   Phrase: Las fake news están influyendo en procesos electorales y debates públicos en múltiples países. | Distance: 21.5732
